# %%
import os
import json
import google.generativeai as genai
import re
import sys


# Set your API key
GOOGLE_API_KEY = "AIzaSyBZpusFDGnAW40XG_B3hlT8jR4kzt0fNXA"
genai.configure(api_key=GOOGLE_API_KEY)

# Load the Gemini Pro model
model = genai.GenerativeModel('gemini-2.0-flash')

SYSTEM_PROMPT = """
Role: You are an expert analyst of investor-entrepreneur interactions on TV shows like Shark Tank or Dragon's Den. Your task is to meticulously analyze the questions asked by the investors (Sharks/Dragons) during a business pitch.

Context: You will be provided with the script of a business pitch and the subsequent Q&A session from a show like Shark Tank or Dragon's Den. Your focus is ONLY on the questions asked BY THE INVESTORS.

Action: Carefully review the conversation. For each question asked by an investor, identify the primary business attribute or area of concern that the question addresses. Select the most relevant category from the comprehensive list provided below. Note that a single question might touch on multiple areas, but you should choose the primary intent of the question.

Structure your response as follows:

Investor (e.g., "Mark Cuban"):

Question: [Exact text of the question]

Primary Category: [Select one category from the list below]

Repeat this format for each question asked by each investor. If a single investor asks multiple questions, list them separately.

Question Categories:

1. Business Fundamentals & Viability:

Business Model: Questions about how the business makes money, revenue streams, pricing strategies, cost structure.

Target Market: Questions about the ideal customer, market size, market segmentation, and understanding of customer needs.

Competition: Questions about competitors, competitive advantages, market share, and barriers to entry.

Differentiation/Unique Selling Proposition (USP): Questions exploring what makes the business stand out from the competition.

Scalability: Questions about the ability to grow the business efficiently and handle increased demand.

Sustainability/Long-Term Vision: Questions about the long-term plans for the business, its ability to adapt to market changes, and its overall vision.

Operations: Questions about the day-to-day running of the business, manufacturing, logistics, and supply chain.

Legal/Regulatory: Questions about patents, trademarks, compliance, and legal risks.

Market Traction: Questions about customer acquisition, sales, and evidence of demand.

Distribution Channels: How the product/service reaches the customer.

2. Financial Performance & Valuation:

Revenue: Questions about current and projected revenue, sales growth, and revenue sources.

Profitability: Questions about profit margins, cost of goods sold, operating expenses, and net profit.

Valuation: Questions about the company's worth, justification for the valuation, and comparable company data.

Financial Projections: Questions about the assumptions behind financial forecasts and the realism of those projections.

Funding/Investment History: Questions about previous funding rounds, use of funds, and current capital structure.

Burn Rate/Cash Flow: Questions about how quickly the company is spending money and its ability to manage cash flow.

Customer Acquisition Cost (CAC): How much it costs to gain a customer.

Lifetime Value of a Customer (LTV): The predicted revenue a customer will generate during their relationship with the company.

3. Product/Service Attributes:

Functionality/Features: Questions about the product's capabilities and specific features.

Innovation/Technology: Questions about the novelty of the product or service, its technology, and intellectual property.

Product Development: Questions about the stage of development, future product roadmap, and development costs.

Manufacturing/Production: Questions related to how the product is made.

Intellectual Property: Questions about patents, trademarks, and other protections.

Usability/User Experience: How easy and enjoyable the product/service is to use.

Quality: Standards and measures taken to ensure the product/service meets expectations.

4. Team & Leadership:

Experience/Expertise: Questions about the team's background, skills, and relevant experience.

Leadership/Management: Questions about the leadership team's vision, strategy, and ability to execute.

Team Dynamics: Questions about the team's relationships, roles, and responsibilities.

Founder Commitment/Motivation: Questions to understand the founders' drive and dedication.

Advisory Board/Mentors: Who is advising the team.

5. Investment & Deal Terms:

Use of Funds: Questions about how the investment will be used to grow the business.

Equity/Ownership: Questions about the percentage of ownership being offered and the existing equity structure.

Exit Strategy: Questions about the potential for a future sale or IPO.

Return on Investment (ROI): Questions to understand the potential return for the investors.

Control/Influence: Questions about the investor's role in the company's decision-making.

6. Market Position & Strategy:

Marketing & Sales Strategy: Questions about how the company plans to reach its target market and generate sales.

Customer Acquisition: Questions about strategies and tactics used to acquire new customers.

Brand Awareness: Questions about building recognition and reputation for the brand.

Pricing Strategy: Questions about the company's approach to setting prices.

Market Trends: How the business is aligned with current trends.

7. Risks & Challenges:

Potential Risks: Questions about potential threats to the business, such as competition, regulatory changes, or economic downturns.

Contingency Plans: Questions about how the company plans to address potential challenges.

Barriers to Entry: Obstacles that prevent new competitors from easily entering the market.

8. Impact & Sustainability:

Social Impact: The business's positive effect on society.

Environmental Impact: The business's effect on the environment.

Ethical Considerations: Questions about the company's adherence to ethical standards.

Example:

Investor: Kevin O'Leary

Question: "What are your gross margins on each unit?"

Primary Category: Profitability

OUTPUT FORMAT:
Provide a JSON object containing the extracted information for each business pitch.
For each investor question, include the investor's name, the exact question asked, and the primary category it falls under.  If an attribute is not mentioned in the transcript, leave it as "not_provided".
For example:

{
  "questions": [
    {
      "Investor": "Mark Cuban",
      "Question": "How do you acquire new customers?",
      "Primary Category": "Customer Acquisition"
    },
    {
      "Investor": "Kevin O'Leary",
      "Question": "What are your gross margins on each unit?",
      "Primary Category": "Profitability"
    },
    {
      "Investor": "Lori Greiner",
      "Question": "Do you have any patents?",
      "Primary Category": "Intellectual Property"
    }
  ]
}
"""


def clean_transcript(transcript):
    # Remove non-printable characters
    transcript = ''.join(c for c in transcript if c.isprintable())
    # Replace problematic characters (example)
    transcript = transcript.replace("’", "'")  # Replace curly apostrophes
    transcript = re.sub(r"[\x00-\x1F\x7F-\xFF]", "", transcript)  # remove control characters and extended ascii
    return transcript

def fix_json(json_string):
    # Remove trailing commas (more robust)
    json_string = re.sub(r",(\s*?[\}\]])", r"\1", json_string)
    return json_string

try:
    import jsonrepair
    def repair_json(json_string):
        try:
            repaired_json_string = jsonrepair.repair_json(json_string)
            return repaired_json_string
        except:
            return None # or raise the exception if you want to know it failed
except ImportError:
    print("Please install jsonrepair package to use repair_json functionality")


def process_pitch(filepath, output_dir):
    """Processes a single pitch file and saves the output JSON."""
    print(f"Starting processing file: {filepath}")  # Indicate file processing start
    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            # Load the JSON data from the input file
            data = json.load(f)

            # Extract questions and investor names
            questions_data = []
            if 'pitches' in data and len(data['pitches']) > 0 and 'questions' in data['pitches'][0]:
                for question_data in data['pitches'][0]['questions']:
                    investor = question_data.get('speaker', 'Unknown Investor')
                    question = question_data.get('raw_text', '')
                    if investor != 'Entrepreneur':  # Only consider investor questions
                        questions_data.append(f"Investor: {investor}\nQuestion: {question}\n")

            transcript = "\n".join(questions_data)

            if not transcript:
                print(f"Error: No questions/responses found in JSON file: {filepath}")
                return

    except FileNotFoundError:
        print(f"Error: File not found: {filepath}")
        return
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in file {filepath}: {e}")
        return
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return

    try:
        # Clean the transcript *before* sending it to the LLM
        transcript = clean_transcript(transcript)

        # Send the transcript and system prompt to the Gemini model
        response = model.generate_content([SYSTEM_PROMPT, transcript])
        response_text = response.text

        # Clean up response text to handle potential markdown
        if response_text.startswith("```json"):
            response_text = response_text[len("```json"):]
        if response_text.endswith("```"):
            response_text = response_text[:-len("```")]
        response_text = response_text.strip() # Remove leading/trailing whitespace

        # Debugging: Print the cleaned response text *before* attempting to load it as JSON
        print("Cleaned Response Text (before fixing):\n", response_text)  # <---- ADDED

        # Try to fix the JSON *before* parsing
        response_text = fix_json(response_text) #Apply simple regex fixes
        if 'jsonrepair' in sys.modules:
            repaired_json = repair_json(response_text) #Try more complex repair
            if repaired_json:
                response_text = repaired_json
                print("JSON was repaired using jsonrepair")
            else:
                print("JSON repair with jsonrepair failed")


        # Extract the JSON from the response.
        try:
            json_output = json.loads(response_text)
            print("JSON loaded successfully!") #debug
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
            print(f"Raw Response text: {response.text}") # Print the original raw response
            print(f"Cleaned Response text: {response_text}") # Print the cleaned text for inspection

            # NEW: Print a snippet of the text around the error location
            #error_line = 802  # Approximate line number from the error  (You may not know the line number now)
            #start_char = max(0, 31584 - 200)  # Show 200 characters before...
            #end_char = 31584 + 200              # ...and 200 characters after
            #print(f"Snippet around error (char 31584):\n", response_text[start_char:end_char])

            #Instead of snippet around specific character print the first 500 characters
            print(f"First 500 characters of JSON for debugging:\n", response_text[:500])

            # Handle the error gracefully:
            # 1. Log the error and the original/fixed JSON
            # 2. Return a default JSON structure with error flags
            # 2. Retry with a simplified prompt, etc.
            return

        # Save the JSON output to a file
        filename = os.path.basename(filepath).replace('.json', '_output.json') # Changed extension
        output_path = os.path.join(output_dir, filename)

        with open(output_path, 'w', encoding='utf-8') as outfile:
            json.dump(json_output, outfile, indent=4)

        print(f"Processed {filepath} and saved output to {output_path}")

    except Exception as e:
        print(f"Error processing {filepath}: {e}")



def process_directory(input_dir, output_dir):
    """Processes all pitch files in a directory, skipping already processed ones."""

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    json_files = [filename for filename in os.listdir(input_dir) if filename.endswith('.json')] # Changed extension
    total_files = len(json_files)
    print(f"Total .json files found in input directory: {total_files}")

    processed_count = 0
    skipped_count = 0

    for index, filename in enumerate(json_files):
        filepath = os.path.join(input_dir, filename)
        output_filename = os.path.basename(filepath).replace('.json', '_output.json') # Changed extension
        output_path = os.path.join(output_dir, output_filename)

        if os.path.exists(output_path):
            print(f"Skipping file {index + 1} of {total_files}: {filename} (already processed)")
            skipped_count += 1
            continue

        print(f"Processing file {index + 1} of {total_files}: {filename}") # Indicate file number and name
        process_pitch(filepath, output_dir)
        processed_count +=1

    print(f"Processing complete.  Processed {processed_count} files, skipped {skipped_count} files.")


# Example Usage:
input_directory = r"C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output"  # Replace with your input directory
output_directory = r"C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\Question_extraction\gemini_2.0"  # Replace with your desired output directory

process_directory(input_directory, output_directory)
print("Processing complete.")
# Out:
# Please install jsonrepair package to use repair_json functionality
# Total .json files found in input directory: 2089
# Skipping file 1 of 2089: pitch_1.json (already processed)
# Skipping file 2 of 2089: pitch_10.json (already processed)
# Skipping file 3 of 2089: pitch_100.json (already processed)
# Skipping file 4 of 2089: pitch_1000.json (already processed)
# Skipping file 5 of 2089: pitch_1001.json (already processed)
# Skipping file 6 of 2089: pitch_1002.json (already processed)
# Skipping file 7 of 2089: pitch_1003.json (already processed)
# Skipping file 8 of 2089: pitch_1004.json (already processed)
# Skipping file 9 of 2089: pitch_1005.json (already processed)
# Skipping file 10 of 2089: pitch_1006.json (already processed)
# Skipping file 11 of 2089: pitch_1007.json (already processed)
# Skipping file 12 of 2089: pitch_1008.json (already processed)
# Skipping file 13 of 2089: pitch_1009.json (already processed)
# Skipping file 14 of 2089: pitch_101.json (already processed)
# Skipping file 15 of 2089: pitch_1010.json (already processed)
# Skipping file 16 of 2089: pitch_1011.json (already processed)
# Skipping file 17 of 2089: pitch_1012.json (already processed)
# Skipping file 18 of 2089: pitch_1013.json (already processed)
# Skipping file 19 of 2089: pitch_1014.json (already processed)
# Skipping file 20 of 2089: pitch_1015.json (already processed)
# Skipping file 21 of 2089: pitch_1016.json (already processed)
# Skipping file 22 of 2089: pitch_1017.json (already processed)
# Skipping file 23 of 2089: pitch_1018.json (already processed)
# Skipping file 24 of 2089: pitch_1019.json (already processed)
# Skipping file 25 of 2089: pitch_102.json (already processed)
# Skipping file 26 of 2089: pitch_1020.json (already processed)
# Skipping file 27 of 2089: pitch_1021.json (already processed)
# Skipping file 28 of 2089: pitch_1022.json (already processed)
# Skipping file 29 of 2089: pitch_1023.json (already processed)
# Skipping file 30 of 2089: pitch_1024.json (already processed)
# Skipping file 31 of 2089: pitch_1025.json (already processed)
# Skipping file 32 of 2089: pitch_1026.json (already processed)
# Skipping file 33 of 2089: pitch_1027.json (already processed)
# Skipping file 34 of 2089: pitch_1028.json (already processed)
# Skipping file 35 of 2089: pitch_1029.json (already processed)
# Skipping file 36 of 2089: pitch_103.json (already processed)
# Skipping file 37 of 2089: pitch_1030.json (already processed)
# Skipping file 38 of 2089: pitch_1031.json (already processed)
# Skipping file 39 of 2089: pitch_1032.json (already processed)
# Skipping file 40 of 2089: pitch_1033.json (already processed)
# Skipping file 41 of 2089: pitch_1034.json (already processed)
# Skipping file 42 of 2089: pitch_1035.json (already processed)
# Skipping file 43 of 2089: pitch_1036.json (already processed)
# Skipping file 44 of 2089: pitch_1037.json (already processed)
# Skipping file 45 of 2089: pitch_1038.json (already processed)
# Skipping file 46 of 2089: pitch_104.json (already processed)
# Skipping file 47 of 2089: pitch_1040.json (already processed)
# Skipping file 48 of 2089: pitch_1041.json (already processed)
# Skipping file 49 of 2089: pitch_1042.json (already processed)
# Skipping file 50 of 2089: pitch_1043.json (already processed)
# Skipping file 51 of 2089: pitch_1044.json (already processed)
# Processing file 52 of 2089: pitch_1045.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1045.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1045.json
# Skipping file 53 of 2089: pitch_1046.json (already processed)
# Skipping file 54 of 2089: pitch_1047.json (already processed)
# Skipping file 55 of 2089: pitch_1048.json (already processed)
# Skipping file 56 of 2089: pitch_1049.json (already processed)
# Skipping file 57 of 2089: pitch_105.json (already processed)
# Skipping file 58 of 2089: pitch_1050.json (already processed)
# Skipping file 59 of 2089: pitch_1051.json (already processed)
# Skipping file 60 of 2089: pitch_1052.json (already processed)
# Skipping file 61 of 2089: pitch_1053.json (already processed)
# Processing file 62 of 2089: pitch_1054.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1054.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1054.json
# Skipping file 63 of 2089: pitch_1055.json (already processed)
# Skipping file 64 of 2089: pitch_1056.json (already processed)
# Skipping file 65 of 2089: pitch_1057.json (already processed)
# Skipping file 66 of 2089: pitch_1058.json (already processed)
# Skipping file 67 of 2089: pitch_1059.json (already processed)
# Skipping file 68 of 2089: pitch_106.json (already processed)
# Skipping file 69 of 2089: pitch_1060.json (already processed)
# Skipping file 70 of 2089: pitch_1061.json (already processed)
# Skipping file 71 of 2089: pitch_1062.json (already processed)
# Skipping file 72 of 2089: pitch_1063.json (already processed)
# Skipping file 73 of 2089: pitch_1064.json (already processed)
# Skipping file 74 of 2089: pitch_1065.json (already processed)
# Skipping file 75 of 2089: pitch_1066.json (already processed)
# Skipping file 76 of 2089: pitch_1067.json (already processed)
# Skipping file 77 of 2089: pitch_1068.json (already processed)
# Skipping file 78 of 2089: pitch_1069.json (already processed)
# Skipping file 79 of 2089: pitch_107.json (already processed)
# Skipping file 80 of 2089: pitch_1070.json (already processed)
# Skipping file 81 of 2089: pitch_1071.json (already processed)
# Skipping file 82 of 2089: pitch_1072.json (already processed)
# Skipping file 83 of 2089: pitch_1073.json (already processed)
# Skipping file 84 of 2089: pitch_1074.json (already processed)
# Skipping file 85 of 2089: pitch_1075.json (already processed)
# Skipping file 86 of 2089: pitch_1076.json (already processed)
# Skipping file 87 of 2089: pitch_1077.json (already processed)
# Skipping file 88 of 2089: pitch_1078.json (already processed)
# Skipping file 89 of 2089: pitch_1079.json (already processed)
# Skipping file 90 of 2089: pitch_108.json (already processed)
# Skipping file 91 of 2089: pitch_1080.json (already processed)
# Skipping file 92 of 2089: pitch_1081.json (already processed)
# Skipping file 93 of 2089: pitch_1082.json (already processed)
# Skipping file 94 of 2089: pitch_1083.json (already processed)
# Skipping file 95 of 2089: pitch_1084.json (already processed)
# Skipping file 96 of 2089: pitch_1085.json (already processed)
# Skipping file 97 of 2089: pitch_1086.json (already processed)
# Skipping file 98 of 2089: pitch_1087.json (already processed)
# Skipping file 99 of 2089: pitch_1088.json (already processed)
# Skipping file 100 of 2089: pitch_1089.json (already processed)
# Skipping file 101 of 2089: pitch_109.json (already processed)
# Skipping file 102 of 2089: pitch_1090.json (already processed)
# Skipping file 103 of 2089: pitch_1091.json (already processed)
# Skipping file 104 of 2089: pitch_1092.json (already processed)
# Skipping file 105 of 2089: pitch_1093.json (already processed)
# Skipping file 106 of 2089: pitch_1094.json (already processed)
# Skipping file 107 of 2089: pitch_1095.json (already processed)
# Skipping file 108 of 2089: pitch_1096.json (already processed)
# Skipping file 109 of 2089: pitch_1097.json (already processed)
# Skipping file 110 of 2089: pitch_1098.json (already processed)
# Skipping file 111 of 2089: pitch_1099.json (already processed)
# Skipping file 112 of 2089: pitch_11.json (already processed)
# Skipping file 113 of 2089: pitch_110.json (already processed)
# Skipping file 114 of 2089: pitch_1100.json (already processed)
# Skipping file 115 of 2089: pitch_1101.json (already processed)
# Skipping file 116 of 2089: pitch_1102.json (already processed)
# Skipping file 117 of 2089: pitch_1103.json (already processed)
# Skipping file 118 of 2089: pitch_1104.json (already processed)
# Skipping file 119 of 2089: pitch_1105.json (already processed)
# Skipping file 120 of 2089: pitch_1106.json (already processed)
# Skipping file 121 of 2089: pitch_1107.json (already processed)
# Skipping file 122 of 2089: pitch_1108.json (already processed)
# Skipping file 123 of 2089: pitch_1109.json (already processed)
# Skipping file 124 of 2089: pitch_111.json (already processed)
# Skipping file 125 of 2089: pitch_1110.json (already processed)
# Skipping file 126 of 2089: pitch_1111.json (already processed)
# Skipping file 127 of 2089: pitch_1112.json (already processed)
# Skipping file 128 of 2089: pitch_1113.json (already processed)
# Skipping file 129 of 2089: pitch_1114.json (already processed)
# Skipping file 130 of 2089: pitch_1116.json (already processed)
# Skipping file 131 of 2089: pitch_1117.json (already processed)
# Skipping file 132 of 2089: pitch_1118.json (already processed)
# Skipping file 133 of 2089: pitch_1119.json (already processed)
# Skipping file 134 of 2089: pitch_112.json (already processed)
# Skipping file 135 of 2089: pitch_1120.json (already processed)
# Skipping file 136 of 2089: pitch_1121.json (already processed)
# Skipping file 137 of 2089: pitch_1122.json (already processed)
# Skipping file 138 of 2089: pitch_1123.json (already processed)
# Skipping file 139 of 2089: pitch_1124.json (already processed)
# Skipping file 140 of 2089: pitch_1125.json (already processed)
# Skipping file 141 of 2089: pitch_1126.json (already processed)
# Skipping file 142 of 2089: pitch_1127.json (already processed)
# Skipping file 143 of 2089: pitch_1128.json (already processed)
# Skipping file 144 of 2089: pitch_1129.json (already processed)
# Skipping file 145 of 2089: pitch_113.json (already processed)
# Skipping file 146 of 2089: pitch_1130.json (already processed)
# Skipping file 147 of 2089: pitch_1131.json (already processed)
# Skipping file 148 of 2089: pitch_1132.json (already processed)
# Skipping file 149 of 2089: pitch_1133.json (already processed)
# Skipping file 150 of 2089: pitch_1134.json (already processed)
# Skipping file 151 of 2089: pitch_1135.json (already processed)
# Skipping file 152 of 2089: pitch_1136.json (already processed)
# Skipping file 153 of 2089: pitch_1137.json (already processed)
# Skipping file 154 of 2089: pitch_1138.json (already processed)
# Skipping file 155 of 2089: pitch_1139.json (already processed)
# Skipping file 156 of 2089: pitch_114.json (already processed)
# Skipping file 157 of 2089: pitch_1145.json (already processed)
# Skipping file 158 of 2089: pitch_1146.json (already processed)
# Skipping file 159 of 2089: pitch_1147.json (already processed)
# Skipping file 160 of 2089: pitch_1148.json (already processed)
# Skipping file 161 of 2089: pitch_1149.json (already processed)
# Skipping file 162 of 2089: pitch_115.json (already processed)
# Skipping file 163 of 2089: pitch_1150.json (already processed)
# Skipping file 164 of 2089: pitch_1151.json (already processed)
# Skipping file 165 of 2089: pitch_1152.json (already processed)
# Skipping file 166 of 2089: pitch_1153.json (already processed)
# Skipping file 167 of 2089: pitch_1154.json (already processed)
# Skipping file 168 of 2089: pitch_1155.json (already processed)
# Skipping file 169 of 2089: pitch_1156.json (already processed)
# Skipping file 170 of 2089: pitch_1157.json (already processed)
# Skipping file 171 of 2089: pitch_1158.json (already processed)
# Skipping file 172 of 2089: pitch_1159.json (already processed)
# Skipping file 173 of 2089: pitch_116.json (already processed)
# Skipping file 174 of 2089: pitch_1160.json (already processed)
# Skipping file 175 of 2089: pitch_1161.json (already processed)
# Skipping file 176 of 2089: pitch_1162.json (already processed)
# Skipping file 177 of 2089: pitch_1163.json (already processed)
# Skipping file 178 of 2089: pitch_1164.json (already processed)
# Skipping file 179 of 2089: pitch_1165.json (already processed)
# Skipping file 180 of 2089: pitch_1166.json (already processed)
# Skipping file 181 of 2089: pitch_1167.json (already processed)
# Skipping file 182 of 2089: pitch_1168.json (already processed)
# Skipping file 183 of 2089: pitch_1169.json (already processed)
# Skipping file 184 of 2089: pitch_117.json (already processed)
# Skipping file 185 of 2089: pitch_1170.json (already processed)
# Skipping file 186 of 2089: pitch_1171.json (already processed)
# Skipping file 187 of 2089: pitch_1172.json (already processed)
# Skipping file 188 of 2089: pitch_1173.json (already processed)
# Skipping file 189 of 2089: pitch_1174.json (already processed)
# Skipping file 190 of 2089: pitch_1175.json (already processed)
# Skipping file 191 of 2089: pitch_1176.json (already processed)
# Skipping file 192 of 2089: pitch_1177.json (already processed)
# Skipping file 193 of 2089: pitch_1178.json (already processed)
# Skipping file 194 of 2089: pitch_1179.json (already processed)
# Skipping file 195 of 2089: pitch_118.json (already processed)
# Skipping file 196 of 2089: pitch_1180.json (already processed)
# Skipping file 197 of 2089: pitch_1181.json (already processed)
# Skipping file 198 of 2089: pitch_1182.json (already processed)
# Skipping file 199 of 2089: pitch_1183.json (already processed)
# Skipping file 200 of 2089: pitch_1184.json (already processed)
# Skipping file 201 of 2089: pitch_1185.json (already processed)
# Skipping file 202 of 2089: pitch_1186.json (already processed)
# Skipping file 203 of 2089: pitch_1187.json (already processed)
# Skipping file 204 of 2089: pitch_1188.json (already processed)
# Skipping file 205 of 2089: pitch_1189.json (already processed)
# Skipping file 206 of 2089: pitch_119.json (already processed)
# Skipping file 207 of 2089: pitch_1190.json (already processed)
# Skipping file 208 of 2089: pitch_1192.json (already processed)
# Skipping file 209 of 2089: pitch_1193.json (already processed)
# Skipping file 210 of 2089: pitch_1194.json (already processed)
# Skipping file 211 of 2089: pitch_1195.json (already processed)
# Skipping file 212 of 2089: pitch_1196.json (already processed)
# Skipping file 213 of 2089: pitch_1197.json (already processed)
# Skipping file 214 of 2089: pitch_1198.json (already processed)
# Skipping file 215 of 2089: pitch_1199.json (already processed)
# Skipping file 216 of 2089: pitch_12.json (already processed)
# Skipping file 217 of 2089: pitch_120.json (already processed)
# Skipping file 218 of 2089: pitch_1200.json (already processed)
# Skipping file 219 of 2089: pitch_1201.json (already processed)
# Skipping file 220 of 2089: pitch_1202.json (already processed)
# Skipping file 221 of 2089: pitch_1203.json (already processed)
# Skipping file 222 of 2089: pitch_1204.json (already processed)
# Skipping file 223 of 2089: pitch_1205.json (already processed)
# Skipping file 224 of 2089: pitch_1206.json (already processed)
# Skipping file 225 of 2089: pitch_1208.json (already processed)
# Skipping file 226 of 2089: pitch_1209.json (already processed)
# Skipping file 227 of 2089: pitch_1210.json (already processed)
# Skipping file 228 of 2089: pitch_1211.json (already processed)
# Skipping file 229 of 2089: pitch_1212.json (already processed)
# Skipping file 230 of 2089: pitch_1213.json (already processed)
# Skipping file 231 of 2089: pitch_1214.json (already processed)
# Skipping file 232 of 2089: pitch_1215.json (already processed)
# Skipping file 233 of 2089: pitch_1216.json (already processed)
# Skipping file 234 of 2089: pitch_1217.json (already processed)
# Skipping file 235 of 2089: pitch_1218.json (already processed)
# Skipping file 236 of 2089: pitch_1219.json (already processed)
# Skipping file 237 of 2089: pitch_122.json (already processed)
# Skipping file 238 of 2089: pitch_1220.json (already processed)
# Skipping file 239 of 2089: pitch_1221.json (already processed)
# Skipping file 240 of 2089: pitch_1222.json (already processed)
# Skipping file 241 of 2089: pitch_1223.json (already processed)
# Skipping file 242 of 2089: pitch_1224.json (already processed)
# Skipping file 243 of 2089: pitch_1225.json (already processed)
# Skipping file 244 of 2089: pitch_1226.json (already processed)
# Skipping file 245 of 2089: pitch_1227.json (already processed)
# Skipping file 246 of 2089: pitch_1228.json (already processed)
# Skipping file 247 of 2089: pitch_1229.json (already processed)
# Skipping file 248 of 2089: pitch_123.json (already processed)
# Skipping file 249 of 2089: pitch_1230.json (already processed)
# Skipping file 250 of 2089: pitch_1231.json (already processed)
# Skipping file 251 of 2089: pitch_1232.json (already processed)
# Skipping file 252 of 2089: pitch_1233.json (already processed)
# Skipping file 253 of 2089: pitch_1234.json (already processed)
# Skipping file 254 of 2089: pitch_1235.json (already processed)
# Skipping file 255 of 2089: pitch_1236.json (already processed)
# Skipping file 256 of 2089: pitch_1237.json (already processed)
# Skipping file 257 of 2089: pitch_1238.json (already processed)
# Skipping file 258 of 2089: pitch_1239.json (already processed)
# Skipping file 259 of 2089: pitch_124.json (already processed)
# Skipping file 260 of 2089: pitch_1240.json (already processed)
# Skipping file 261 of 2089: pitch_1241.json (already processed)
# Skipping file 262 of 2089: pitch_1242.json (already processed)
# Skipping file 263 of 2089: pitch_1243.json (already processed)
# Skipping file 264 of 2089: pitch_1244.json (already processed)
# Skipping file 265 of 2089: pitch_1245.json (already processed)
# Skipping file 266 of 2089: pitch_1246.json (already processed)
# Skipping file 267 of 2089: pitch_1247.json (already processed)
# Skipping file 268 of 2089: pitch_1248.json (already processed)
# Skipping file 269 of 2089: pitch_125.json (already processed)
# Skipping file 270 of 2089: pitch_1250.json (already processed)
# Skipping file 271 of 2089: pitch_1251.json (already processed)
# Skipping file 272 of 2089: pitch_1252.json (already processed)
# Skipping file 273 of 2089: pitch_1253.json (already processed)
# Skipping file 274 of 2089: pitch_1254.json (already processed)
# Skipping file 275 of 2089: pitch_1255.json (already processed)
# Skipping file 276 of 2089: pitch_1256.json (already processed)
# Skipping file 277 of 2089: pitch_1257.json (already processed)
# Skipping file 278 of 2089: pitch_1258.json (already processed)
# Skipping file 279 of 2089: pitch_1259.json (already processed)
# Skipping file 280 of 2089: pitch_126.json (already processed)
# Skipping file 281 of 2089: pitch_1260.json (already processed)
# Skipping file 282 of 2089: pitch_1262.json (already processed)
# Skipping file 283 of 2089: pitch_1263.json (already processed)
# Skipping file 284 of 2089: pitch_1264.json (already processed)
# Skipping file 285 of 2089: pitch_1265.json (already processed)
# Processing file 286 of 2089: pitch_1266.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1266.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1266.json
# Skipping file 287 of 2089: pitch_1267.json (already processed)
# Skipping file 288 of 2089: pitch_1268.json (already processed)
# Skipping file 289 of 2089: pitch_1269.json (already processed)
# Skipping file 290 of 2089: pitch_127.json (already processed)
# Skipping file 291 of 2089: pitch_1270.json (already processed)
# Skipping file 292 of 2089: pitch_1271.json (already processed)
# Skipping file 293 of 2089: pitch_1272.json (already processed)
# Skipping file 294 of 2089: pitch_1273.json (already processed)
# Skipping file 295 of 2089: pitch_1274.json (already processed)
# Skipping file 296 of 2089: pitch_1275.json (already processed)
# Skipping file 297 of 2089: pitch_1276.json (already processed)
# Skipping file 298 of 2089: pitch_1277.json (already processed)
# Skipping file 299 of 2089: pitch_1278.json (already processed)
# Skipping file 300 of 2089: pitch_1279.json (already processed)
# Skipping file 301 of 2089: pitch_128.json (already processed)
# Skipping file 302 of 2089: pitch_1280.json (already processed)
# Skipping file 303 of 2089: pitch_1281.json (already processed)
# Skipping file 304 of 2089: pitch_1282.json (already processed)
# Skipping file 305 of 2089: pitch_1283.json (already processed)
# Skipping file 306 of 2089: pitch_1284.json (already processed)
# Skipping file 307 of 2089: pitch_1285.json (already processed)
# Skipping file 308 of 2089: pitch_1286.json (already processed)
# Skipping file 309 of 2089: pitch_1287.json (already processed)
# Skipping file 310 of 2089: pitch_1288.json (already processed)
# Skipping file 311 of 2089: pitch_1289.json (already processed)
# Skipping file 312 of 2089: pitch_129.json (already processed)
# Skipping file 313 of 2089: pitch_1290.json (already processed)
# Skipping file 314 of 2089: pitch_1292.json (already processed)
# Skipping file 315 of 2089: pitch_1293.json (already processed)
# Skipping file 316 of 2089: pitch_1294.json (already processed)
# Skipping file 317 of 2089: pitch_1295.json (already processed)
# Skipping file 318 of 2089: pitch_1296.json (already processed)
# Skipping file 319 of 2089: pitch_1297.json (already processed)
# Skipping file 320 of 2089: pitch_1298.json (already processed)
# Skipping file 321 of 2089: pitch_1299.json (already processed)
# Skipping file 322 of 2089: pitch_13.json (already processed)
# Skipping file 323 of 2089: pitch_130.json (already processed)
# Skipping file 324 of 2089: pitch_1301.json (already processed)
# Skipping file 325 of 2089: pitch_1302.json (already processed)
# Skipping file 326 of 2089: pitch_1303.json (already processed)
# Skipping file 327 of 2089: pitch_1304.json (already processed)
# Skipping file 328 of 2089: pitch_1305.json (already processed)
# Skipping file 329 of 2089: pitch_1306.json (already processed)
# Skipping file 330 of 2089: pitch_1307.json (already processed)
# Skipping file 331 of 2089: pitch_1308.json (already processed)
# Skipping file 332 of 2089: pitch_1309.json (already processed)
# Skipping file 333 of 2089: pitch_131.json (already processed)
# Skipping file 334 of 2089: pitch_1310.json (already processed)
# Skipping file 335 of 2089: pitch_1311.json (already processed)
# Skipping file 336 of 2089: pitch_1312.json (already processed)
# Skipping file 337 of 2089: pitch_1313.json (already processed)
# Skipping file 338 of 2089: pitch_1314.json (already processed)
# Skipping file 339 of 2089: pitch_1315.json (already processed)
# Skipping file 340 of 2089: pitch_1316.json (already processed)
# Skipping file 341 of 2089: pitch_1317.json (already processed)
# Skipping file 342 of 2089: pitch_1318.json (already processed)
# Skipping file 343 of 2089: pitch_1319.json (already processed)
# Skipping file 344 of 2089: pitch_132.json (already processed)
# Skipping file 345 of 2089: pitch_1320.json (already processed)
# Skipping file 346 of 2089: pitch_1321.json (already processed)
# Skipping file 347 of 2089: pitch_1322.json (already processed)
# Skipping file 348 of 2089: pitch_1323.json (already processed)
# Skipping file 349 of 2089: pitch_1324.json (already processed)
# Skipping file 350 of 2089: pitch_1325.json (already processed)
# Skipping file 351 of 2089: pitch_1326.json (already processed)
# Skipping file 352 of 2089: pitch_1327.json (already processed)
# Skipping file 353 of 2089: pitch_1328.json (already processed)
# Skipping file 354 of 2089: pitch_1329.json (already processed)
# Skipping file 355 of 2089: pitch_133.json (already processed)
# Skipping file 356 of 2089: pitch_1330.json (already processed)
# Skipping file 357 of 2089: pitch_1331.json (already processed)
# Skipping file 358 of 2089: pitch_1332.json (already processed)
# Skipping file 359 of 2089: pitch_1333.json (already processed)
# Skipping file 360 of 2089: pitch_1334.json (already processed)
# Skipping file 361 of 2089: pitch_1335.json (already processed)
# Skipping file 362 of 2089: pitch_1336.json (already processed)
# Skipping file 363 of 2089: pitch_1337.json (already processed)
# Skipping file 364 of 2089: pitch_1338.json (already processed)
# Skipping file 365 of 2089: pitch_1339.json (already processed)
# Skipping file 366 of 2089: pitch_134.json (already processed)
# Skipping file 367 of 2089: pitch_1340.json (already processed)
# Skipping file 368 of 2089: pitch_1341.json (already processed)
# Skipping file 369 of 2089: pitch_1342.json (already processed)
# Skipping file 370 of 2089: pitch_1343.json (already processed)
# Skipping file 371 of 2089: pitch_1345.json (already processed)
# Skipping file 372 of 2089: pitch_1346.json (already processed)
# Skipping file 373 of 2089: pitch_1347.json (already processed)
# Skipping file 374 of 2089: pitch_1348.json (already processed)
# Skipping file 375 of 2089: pitch_1349.json (already processed)
# Skipping file 376 of 2089: pitch_135.json (already processed)
# Skipping file 377 of 2089: pitch_1350.json (already processed)
# Skipping file 378 of 2089: pitch_1351.json (already processed)
# Skipping file 379 of 2089: pitch_1352.json (already processed)
# Skipping file 380 of 2089: pitch_1353.json (already processed)
# Skipping file 381 of 2089: pitch_1354.json (already processed)
# Skipping file 382 of 2089: pitch_1356.json (already processed)
# Skipping file 383 of 2089: pitch_1357.json (already processed)
# Skipping file 384 of 2089: pitch_1358.json (already processed)
# Skipping file 385 of 2089: pitch_1359.json (already processed)
# Skipping file 386 of 2089: pitch_136.json (already processed)
# Skipping file 387 of 2089: pitch_1360.json (already processed)
# Skipping file 388 of 2089: pitch_1361.json (already processed)
# Skipping file 389 of 2089: pitch_1362.json (already processed)
# Skipping file 390 of 2089: pitch_1363.json (already processed)
# Skipping file 391 of 2089: pitch_1364.json (already processed)
# Skipping file 392 of 2089: pitch_1365.json (already processed)
# Skipping file 393 of 2089: pitch_1366.json (already processed)
# Skipping file 394 of 2089: pitch_1367.json (already processed)
# Skipping file 395 of 2089: pitch_1368.json (already processed)
# Skipping file 396 of 2089: pitch_1369.json (already processed)
# Skipping file 397 of 2089: pitch_137.json (already processed)
# Skipping file 398 of 2089: pitch_1370.json (already processed)
# Skipping file 399 of 2089: pitch_1371.json (already processed)
# Skipping file 400 of 2089: pitch_1372.json (already processed)
# Skipping file 401 of 2089: pitch_1373.json (already processed)
# Skipping file 402 of 2089: pitch_1374.json (already processed)
# Skipping file 403 of 2089: pitch_1375.json (already processed)
# Skipping file 404 of 2089: pitch_1377.json (already processed)
# Processing file 405 of 2089: pitch_1378.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1378.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1378.json
# Skipping file 406 of 2089: pitch_1379.json (already processed)
# Skipping file 407 of 2089: pitch_138.json (already processed)
# Skipping file 408 of 2089: pitch_1380.json (already processed)
# Skipping file 409 of 2089: pitch_1381.json (already processed)
# Skipping file 410 of 2089: pitch_1382.json (already processed)
# Skipping file 411 of 2089: pitch_1383.json (already processed)
# Skipping file 412 of 2089: pitch_1384.json (already processed)
# Skipping file 413 of 2089: pitch_1385.json (already processed)
# Skipping file 414 of 2089: pitch_1386.json (already processed)
# Skipping file 415 of 2089: pitch_1387.json (already processed)
# Skipping file 416 of 2089: pitch_1388.json (already processed)
# Skipping file 417 of 2089: pitch_1389.json (already processed)
# Skipping file 418 of 2089: pitch_139.json (already processed)
# Skipping file 419 of 2089: pitch_1390.json (already processed)
# Skipping file 420 of 2089: pitch_1391.json (already processed)
# Skipping file 421 of 2089: pitch_1392.json (already processed)
# Skipping file 422 of 2089: pitch_1393.json (already processed)
# Skipping file 423 of 2089: pitch_1394.json (already processed)
# Skipping file 424 of 2089: pitch_1395.json (already processed)
# Skipping file 425 of 2089: pitch_1396.json (already processed)
# Skipping file 426 of 2089: pitch_1397.json (already processed)
# Skipping file 427 of 2089: pitch_1398.json (already processed)
# Skipping file 428 of 2089: pitch_1399.json (already processed)
# Skipping file 429 of 2089: pitch_14.json (already processed)
# Skipping file 430 of 2089: pitch_140.json (already processed)
# Skipping file 431 of 2089: pitch_1400.json (already processed)
# Skipping file 432 of 2089: pitch_1401.json (already processed)
# Skipping file 433 of 2089: pitch_1402.json (already processed)
# Skipping file 434 of 2089: pitch_1403.json (already processed)
# Skipping file 435 of 2089: pitch_1404.json (already processed)
# Skipping file 436 of 2089: pitch_1405.json (already processed)
# Skipping file 437 of 2089: pitch_1406.json (already processed)
# Skipping file 438 of 2089: pitch_1407.json (already processed)
# Skipping file 439 of 2089: pitch_1408.json (already processed)
# Skipping file 440 of 2089: pitch_1409.json (already processed)
# Skipping file 441 of 2089: pitch_141.json (already processed)
# Skipping file 442 of 2089: pitch_1410.json (already processed)
# Skipping file 443 of 2089: pitch_1411.json (already processed)
# Skipping file 444 of 2089: pitch_1412.json (already processed)
# Skipping file 445 of 2089: pitch_1413.json (already processed)
# Skipping file 446 of 2089: pitch_1414.json (already processed)
# Skipping file 447 of 2089: pitch_1415.json (already processed)
# Skipping file 448 of 2089: pitch_1417.json (already processed)
# Skipping file 449 of 2089: pitch_1418.json (already processed)
# Skipping file 450 of 2089: pitch_1419.json (already processed)
# Skipping file 451 of 2089: pitch_142.json (already processed)
# Skipping file 452 of 2089: pitch_1420.json (already processed)
# Skipping file 453 of 2089: pitch_1421.json (already processed)
# Skipping file 454 of 2089: pitch_1422.json (already processed)
# Skipping file 455 of 2089: pitch_1423.json (already processed)
# Skipping file 456 of 2089: pitch_1424.json (already processed)
# Skipping file 457 of 2089: pitch_1425.json (already processed)
# Skipping file 458 of 2089: pitch_1426.json (already processed)
# Skipping file 459 of 2089: pitch_1427.json (already processed)
# Skipping file 460 of 2089: pitch_1428.json (already processed)
# Skipping file 461 of 2089: pitch_1429.json (already processed)
# Skipping file 462 of 2089: pitch_1430.json (already processed)
# Skipping file 463 of 2089: pitch_1431.json (already processed)
# Skipping file 464 of 2089: pitch_1432.json (already processed)
# Skipping file 465 of 2089: pitch_1433.json (already processed)
# Skipping file 466 of 2089: pitch_1434.json (already processed)
# Skipping file 467 of 2089: pitch_1435.json (already processed)
# Skipping file 468 of 2089: pitch_1436.json (already processed)
# Skipping file 469 of 2089: pitch_1437.json (already processed)
# Skipping file 470 of 2089: pitch_1438.json (already processed)
# Skipping file 471 of 2089: pitch_1439.json (already processed)
# Skipping file 472 of 2089: pitch_144.json (already processed)
# Skipping file 473 of 2089: pitch_1440.json (already processed)
# Skipping file 474 of 2089: pitch_1441.json (already processed)
# Skipping file 475 of 2089: pitch_1442.json (already processed)
# Skipping file 476 of 2089: pitch_1443.json (already processed)
# Skipping file 477 of 2089: pitch_1444.json (already processed)
# Skipping file 478 of 2089: pitch_1445.json (already processed)
# Skipping file 479 of 2089: pitch_1446.json (already processed)
# Skipping file 480 of 2089: pitch_1447.json (already processed)
# Skipping file 481 of 2089: pitch_1449.json (already processed)
# Skipping file 482 of 2089: pitch_145.json (already processed)
# Skipping file 483 of 2089: pitch_1450.json (already processed)
# Skipping file 484 of 2089: pitch_1451.json (already processed)
# Skipping file 485 of 2089: pitch_1452.json (already processed)
# Skipping file 486 of 2089: pitch_1453.json (already processed)
# Skipping file 487 of 2089: pitch_1454.json (already processed)
# Skipping file 488 of 2089: pitch_1455.json (already processed)
# Skipping file 489 of 2089: pitch_1456.json (already processed)
# Skipping file 490 of 2089: pitch_1457.json (already processed)
# Skipping file 491 of 2089: pitch_1458.json (already processed)
# Skipping file 492 of 2089: pitch_1459.json (already processed)
# Skipping file 493 of 2089: pitch_146.json (already processed)
# Skipping file 494 of 2089: pitch_1460.json (already processed)
# Skipping file 495 of 2089: pitch_1461.json (already processed)
# Skipping file 496 of 2089: pitch_1462.json (already processed)
# Skipping file 497 of 2089: pitch_1463.json (already processed)
# Skipping file 498 of 2089: pitch_1464.json (already processed)
# Skipping file 499 of 2089: pitch_1465.json (already processed)
# Skipping file 500 of 2089: pitch_1466.json (already processed)
# Skipping file 501 of 2089: pitch_1467.json (already processed)
# Skipping file 502 of 2089: pitch_1468.json (already processed)
# Skipping file 503 of 2089: pitch_1469.json (already processed)
# Skipping file 504 of 2089: pitch_147.json (already processed)
# Skipping file 505 of 2089: pitch_1470.json (already processed)
# Skipping file 506 of 2089: pitch_1471.json (already processed)
# Skipping file 507 of 2089: pitch_1472.json (already processed)
# Skipping file 508 of 2089: pitch_1473.json (already processed)
# Skipping file 509 of 2089: pitch_1474.json (already processed)
# Skipping file 510 of 2089: pitch_1475.json (already processed)
# Skipping file 511 of 2089: pitch_1476.json (already processed)
# Skipping file 512 of 2089: pitch_1478.json (already processed)
# Skipping file 513 of 2089: pitch_1479.json (already processed)
# Skipping file 514 of 2089: pitch_148.json (already processed)
# Skipping file 515 of 2089: pitch_1480.json (already processed)
# Skipping file 516 of 2089: pitch_1481.json (already processed)
# Skipping file 517 of 2089: pitch_1482.json (already processed)
# Skipping file 518 of 2089: pitch_1483.json (already processed)
# Skipping file 519 of 2089: pitch_1484.json (already processed)
# Skipping file 520 of 2089: pitch_1485.json (already processed)
# Skipping file 521 of 2089: pitch_1486.json (already processed)
# Skipping file 522 of 2089: pitch_1487.json (already processed)
# Skipping file 523 of 2089: pitch_1488.json (already processed)
# Skipping file 524 of 2089: pitch_1489.json (already processed)
# Skipping file 525 of 2089: pitch_1490.json (already processed)
# Skipping file 526 of 2089: pitch_1491.json (already processed)
# Skipping file 527 of 2089: pitch_1492.json (already processed)
# Skipping file 528 of 2089: pitch_1493.json (already processed)
# Skipping file 529 of 2089: pitch_1494.json (already processed)
# Skipping file 530 of 2089: pitch_1495.json (already processed)
# Skipping file 531 of 2089: pitch_1496.json (already processed)
# Skipping file 532 of 2089: pitch_1497.json (already processed)
# Skipping file 533 of 2089: pitch_1498.json (already processed)
# Skipping file 534 of 2089: pitch_1499.json (already processed)
# Skipping file 535 of 2089: pitch_15.json (already processed)
# Skipping file 536 of 2089: pitch_150.json (already processed)
# Skipping file 537 of 2089: pitch_1500.json (already processed)
# Skipping file 538 of 2089: pitch_1501.json (already processed)
# Skipping file 539 of 2089: pitch_1502.json (already processed)
# Skipping file 540 of 2089: pitch_1503.json (already processed)
# Skipping file 541 of 2089: pitch_1504.json (already processed)
# Skipping file 542 of 2089: pitch_1505.json (already processed)
# Skipping file 543 of 2089: pitch_1506.json (already processed)
# Skipping file 544 of 2089: pitch_1507.json (already processed)
# Skipping file 545 of 2089: pitch_1508.json (already processed)
# Skipping file 546 of 2089: pitch_1509.json (already processed)
# Skipping file 547 of 2089: pitch_151.json (already processed)
# Skipping file 548 of 2089: pitch_1510.json (already processed)
# Skipping file 549 of 2089: pitch_1511.json (already processed)
# Skipping file 550 of 2089: pitch_1512.json (already processed)
# Skipping file 551 of 2089: pitch_1513.json (already processed)
# Skipping file 552 of 2089: pitch_1514.json (already processed)
# Skipping file 553 of 2089: pitch_1515.json (already processed)
# Skipping file 554 of 2089: pitch_1516.json (already processed)
# Skipping file 555 of 2089: pitch_1517.json (already processed)
# Skipping file 556 of 2089: pitch_1519.json (already processed)
# Skipping file 557 of 2089: pitch_152.json (already processed)
# Skipping file 558 of 2089: pitch_1520.json (already processed)
# Skipping file 559 of 2089: pitch_1521.json (already processed)
# Skipping file 560 of 2089: pitch_1522.json (already processed)
# Skipping file 561 of 2089: pitch_1523.json (already processed)
# Skipping file 562 of 2089: pitch_1524.json (already processed)
# Skipping file 563 of 2089: pitch_1525.json (already processed)
# Skipping file 564 of 2089: pitch_1526.json (already processed)
# Skipping file 565 of 2089: pitch_1527.json (already processed)
# Skipping file 566 of 2089: pitch_1528.json (already processed)
# Skipping file 567 of 2089: pitch_1529.json (already processed)
# Skipping file 568 of 2089: pitch_153.json (already processed)
# Skipping file 569 of 2089: pitch_1530.json (already processed)
# Skipping file 570 of 2089: pitch_1531.json (already processed)
# Skipping file 571 of 2089: pitch_1532.json (already processed)
# Skipping file 572 of 2089: pitch_1533.json (already processed)
# Skipping file 573 of 2089: pitch_1534.json (already processed)
# Skipping file 574 of 2089: pitch_1535.json (already processed)
# Skipping file 575 of 2089: pitch_1536.json (already processed)
# Skipping file 576 of 2089: pitch_1537.json (already processed)
# Skipping file 577 of 2089: pitch_1538.json (already processed)
# Skipping file 578 of 2089: pitch_1539.json (already processed)
# Skipping file 579 of 2089: pitch_154.json (already processed)
# Skipping file 580 of 2089: pitch_1540.json (already processed)
# Skipping file 581 of 2089: pitch_1541.json (already processed)
# Skipping file 582 of 2089: pitch_1542.json (already processed)
# Skipping file 583 of 2089: pitch_1543.json (already processed)
# Skipping file 584 of 2089: pitch_1544.json (already processed)
# Skipping file 585 of 2089: pitch_1545.json (already processed)
# Skipping file 586 of 2089: pitch_1546.json (already processed)
# Skipping file 587 of 2089: pitch_1547.json (already processed)
# Skipping file 588 of 2089: pitch_1548.json (already processed)
# Skipping file 589 of 2089: pitch_1549.json (already processed)
# Skipping file 590 of 2089: pitch_155.json (already processed)
# Skipping file 591 of 2089: pitch_1550.json (already processed)
# Processing file 592 of 2089: pitch_1551.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1551.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1551.json
# Processing file 593 of 2089: pitch_1552.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1552.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1552.json
# Skipping file 594 of 2089: pitch_1553.json (already processed)
# Skipping file 595 of 2089: pitch_1554.json (already processed)
# Skipping file 596 of 2089: pitch_1555.json (already processed)
# Skipping file 597 of 2089: pitch_1556.json (already processed)
# Skipping file 598 of 2089: pitch_1557.json (already processed)
# Skipping file 599 of 2089: pitch_1558.json (already processed)
# Skipping file 600 of 2089: pitch_1559.json (already processed)
# Skipping file 601 of 2089: pitch_156.json (already processed)
# Skipping file 602 of 2089: pitch_1560.json (already processed)
# Skipping file 603 of 2089: pitch_1561.json (already processed)
# Skipping file 604 of 2089: pitch_1562.json (already processed)
# Skipping file 605 of 2089: pitch_1563.json (already processed)
# Skipping file 606 of 2089: pitch_1564.json (already processed)
# Skipping file 607 of 2089: pitch_1565.json (already processed)
# Skipping file 608 of 2089: pitch_1566.json (already processed)
# Skipping file 609 of 2089: pitch_1567.json (already processed)
# Skipping file 610 of 2089: pitch_1568.json (already processed)
# Skipping file 611 of 2089: pitch_157.json (already processed)
# Skipping file 612 of 2089: pitch_1570.json (already processed)
# Skipping file 613 of 2089: pitch_1572.json (already processed)
# Skipping file 614 of 2089: pitch_1573.json (already processed)
# Skipping file 615 of 2089: pitch_1574.json (already processed)
# Skipping file 616 of 2089: pitch_1575.json (already processed)
# Skipping file 617 of 2089: pitch_1576.json (already processed)
# Skipping file 618 of 2089: pitch_1577.json (already processed)
# Skipping file 619 of 2089: pitch_1578.json (already processed)
# Skipping file 620 of 2089: pitch_1579.json (already processed)
# Skipping file 621 of 2089: pitch_158.json (already processed)
# Skipping file 622 of 2089: pitch_1580.json (already processed)
# Skipping file 623 of 2089: pitch_1581.json (already processed)
# Skipping file 624 of 2089: pitch_1584.json (already processed)
# Skipping file 625 of 2089: pitch_1585.json (already processed)
# Skipping file 626 of 2089: pitch_1586.json (already processed)
# Skipping file 627 of 2089: pitch_1587.json (already processed)
# Skipping file 628 of 2089: pitch_1588.json (already processed)
# Skipping file 629 of 2089: pitch_1589.json (already processed)
# Skipping file 630 of 2089: pitch_159.json (already processed)
# Skipping file 631 of 2089: pitch_1590.json (already processed)
# Skipping file 632 of 2089: pitch_1591.json (already processed)
# Skipping file 633 of 2089: pitch_1592.json (already processed)
# Skipping file 634 of 2089: pitch_1593.json (already processed)
# Skipping file 635 of 2089: pitch_1594.json (already processed)
# Skipping file 636 of 2089: pitch_1595.json (already processed)
# Skipping file 637 of 2089: pitch_1596.json (already processed)
# Skipping file 638 of 2089: pitch_1597.json (already processed)
# Skipping file 639 of 2089: pitch_1598.json (already processed)
# Skipping file 640 of 2089: pitch_1599.json (already processed)
# Skipping file 641 of 2089: pitch_16.json (already processed)
# Skipping file 642 of 2089: pitch_160.json (already processed)
# Skipping file 643 of 2089: pitch_1600.json (already processed)
# Skipping file 644 of 2089: pitch_1601.json (already processed)
# Skipping file 645 of 2089: pitch_1602.json (already processed)
# Skipping file 646 of 2089: pitch_1603.json (already processed)
# Skipping file 647 of 2089: pitch_1604.json (already processed)
# Skipping file 648 of 2089: pitch_1605.json (already processed)
# Skipping file 649 of 2089: pitch_1606.json (already processed)
# Skipping file 650 of 2089: pitch_1607.json (already processed)
# Skipping file 651 of 2089: pitch_1608.json (already processed)
# Skipping file 652 of 2089: pitch_1609.json (already processed)
# Skipping file 653 of 2089: pitch_161.json (already processed)
# Skipping file 654 of 2089: pitch_1611.json (already processed)
# Skipping file 655 of 2089: pitch_1612.json (already processed)
# Skipping file 656 of 2089: pitch_1613.json (already processed)
# Skipping file 657 of 2089: pitch_1614.json (already processed)
# Skipping file 658 of 2089: pitch_1615.json (already processed)
# Processing file 659 of 2089: pitch_1616.json
# Starting processing file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1616.json
# Error: No questions/responses found in JSON file: C:\Users\adhil\OneDrive\Documents\letsgetmoving-project\task-2\gemini_2oflash json output\pitch_1616.json
# Skipping file 660 of 2089: pitch_1617.json (already processed)
# Skipping file 661 of 2089: pitch_1618.json (already processed)
# Skipping file 662 of 2089: pitch_1619.json (already processed)
# Skipping file 663 of 2089: pitch_162.json (already processed)
# Skipping file 664 of 2089: pitch_1620.json (already processed)
# Skipping file 665 of 2089: pitch_1621.json (already processed)
# Skipping file 666 of 2089: pitch_1622.json (already processed)
# Skipping file 667 of 2089: pitch_1623.json (already processed)
# Skipping file 668 of 2089: pitch_1624.json (already processed)
# Skipping file 669 of 2089: pitch_1625.json (already processed)
# Skipping file 670 of 2089: pitch_1626.json (already processed)
# Skipping file 671 of 2089: pitch_1627.json (already processed)
# Skipping file 672 of 2089: pitch_1628.json (already processed)
# Skipping file 673 of 2089: pitch_1629.json (already processed)
# Skipping file 674 of 2089: pitch_163.json (already processed)
# Skipping file 675 of 2089: pitch_1630.json (already processed)
# Skipping file 676 of 2089: pitch_1631.json (already processed)
# Skipping file 677 of 2089: pitch_1632.json (already processed)
# Skipping file 678 of 2089: pitch_1633.json (already processed)
# Skipping file 679 of 2089: pitch_1634.json (already processed)
# Skipping file 680 of 2089: pitch_1635.json (already processed)
# Skipping file 681 of 2089: pitch_1637.json (already processed)
# Skipping file 682 of 2089: pitch_1638.json (already processed)
# Skipping file 683 of 2089: pitch_1639.json (already processed)
# Skipping file 684 of 2089: pitch_164.json (already processed)
# Skipping file 685 of 2089: pitch_1640.json (already processed)
# Skipping file 686 of 2089: pitch_1642.json (already processed)
# Skipping file 687 of 2089: pitch_1643.json (already processed)
# Skipping file 688 of 2089: pitch_1644.json (already processed)
# Skipping file 689 of 2089: pitch_1645.json (already processed)
# Skipping file 690 of 2089: pitch_1646.json (already processed)
# Skipping file 691 of 2089: pitch_1647.json (already processed)
# Skipping file 692 of 2089: pitch_1648.json (already processed)
# Skipping file 693 of 2089: pitch_1649.json (already processed)
# Skipping file 694 of 2089: pitch_165.json (already processed)
# Skipping file 695 of 2089: pitch_1650.json (already processed)
# Skipping file 696 of 2089: pitch_1651.json (already processed)
# Skipping file 697 of 2089: pitch_1652.json (already processed)
# Skipping file 698 of 2089: pitch_1654.json (already processed)
# Skipping file 699 of 2089: pitch_1655.json (already processed)
# Skipping file 700 of 2089: pitch_1656.json (already processed)
# Skipping file 701 of 2089: pitch_1657.json (already processed)
# Skipping file 702 of 2089: pitch_1658.json (already processed)
# Skipping file 703 of 2089: pitch_1659.json (already processed)
# Skipping file 704 of 2089: pitch_166.json (already processed)
# Skipping file 705 of 2089: pitch_1660.json (already processed)
# Skipping file 706 of 2089: pitch_1661.json (already processed)
# Skipping file 707 of 2089: pitch_1662.json (already processed)
# Skipping file 708 of 2089: pitch_1663.json (already processed)
# Skipping file 709 of 2089: pitch_1664.json (already processed)
# Skipping file 710 of 2089: pitch_1665.json (already processed)
# Skipping file 711 of 2089: pitch_1666.json (already processed)
# Skipping file 712 of 2089: pitch_1667.json (already processed)
# Skipping file 713 of 2089: pitch_1668.json (already processed)
# Skipping file 714 of 2089: pitch_1669.json (already processed)
# Skipping file 715 of 2089: pitch_167.json (already processed)
# Skipping file 716 of 2089: pitch_1670.json (already processed)
# Skipping file 717 of 2089: pitch_1671.json (already processed)
# Skipping file 718 of 2089: pitch_1672.json (already processed)
# Skipping file 719 of 2089: pitch_1673.json (already processed)
# Skipping file 720 of 2089: pitch_1674.json (already processed)
# Skipping file 721 of 2089: pitch_1675.json (already processed)
# Skipping file 722 of 2089: pitch_1676.json (already processed)
# Skipping file 723 of 2089: pitch_1677.json (already processed)
# Skipping file 724 of 2089: pitch_1678.json (already processed)
# Skipping file 725 of 2089: pitch_1679.json (already processed)
# Skipping file 726 of 2089: pitch_168.json (already processed)
# Skipping file 727 of 2089: pitch_1680.json (already processed)
# Skipping file 728 of 2089: pitch_1682.json (already processed)
# Skipping file 729 of 2089: pitch_1683.json (already processed)
# Skipping file 730 of 2089: pitch_1684.json (already processed)
# Skipping file 731 of 2089: pitch_1685.json (already processed)
# Skipping file 732 of 2089: pitch_1686.json (already processed)
# Skipping file 733 of 2089: pitch_1687.json (already processed)
# ...
# Skipping file 1837 of 2089: pitch_75.json (already processed)
# Skipping file 1838 of 2089: pitch_750.json (already processed)
# Skipping file 1839 of 2089: pitch_751.json (already processed)
# Skipping file 1840 of 2089: pitch_752.json (already processed)
# Skipping file 1841 of 2089: pitch_753.json (already processed)
# Skipping file 1842 of 2089: pitch_754.json (already processed)
# Skipping file 1843 of 2089: pitch_755.json (already processed)
# Skipping file 1844 of 2089: pitch_756.json (already processed)
# Skipping file 1845 of 2089: pitch_757.json (already processed)
# Skipping file 1846 of 2089: pitch_758.json (already processed)
# Skipping file 1847 of 2089: pitch_759.json (already processed)
# Skipping file 1848 of 2089: pitch_76.json (already processed)
# Skipping file 1849 of 2089: pitch_760.json (already processed)
# Skipping file 1850 of 2089: pitch_761.json (already processed)
# Skipping file 1851 of 2089: pitch_762.json (already processed)
# Skipping file 1852 of 2089: pitch_763.json (already processed)
# Skipping file 1853 of 2089: pitch_764.json (already processed)
# Skipping file 1854 of 2089: pitch_765.json (already processed)
# Skipping file 1855 of 2089: pitch_766.json (already processed)
# Skipping file 1856 of 2089: pitch_767.json (already processed)
# Skipping file 1857 of 2089: pitch_768.json (already processed)
# Skipping file 1858 of 2089: pitch_769.json (already processed)
# Skipping file 1859 of 2089: pitch_77.json (already processed)
# Skipping file 1860 of 2089: pitch_770.json (already processed)
# Skipping file 1861 of 2089: pitch_771.json (already processed)
# Skipping file 1862 of 2089: pitch_772.json (already processed)
# Skipping file 1863 of 2089: pitch_773.json (already processed)
# Skipping file 1864 of 2089: pitch_774.json (already processed)
# Skipping file 1865 of 2089: pitch_775.json (already processed)
# Skipping file 1866 of 2089: pitch_776.json (already processed)
# Skipping file 1867 of 2089: pitch_777.json (already processed)
# Skipping file 1868 of 2089: pitch_778.json (already processed)
# Skipping file 1869 of 2089: pitch_779.json (already processed)
# Skipping file 1870 of 2089: pitch_78.json (already processed)
# Skipping file 1871 of 2089: pitch_780.json (already processed)
# Skipping file 1872 of 2089: pitch_781.json (already processed)
# Skipping file 1873 of 2089: pitch_782.json (already processed)
# Skipping file 1874 of 2089: pitch_783.json (already processed)
# Skipping file 1875 of 2089: pitch_784.json (already processed)
# Skipping file 1876 of 2089: pitch_785.json (already processed)
# Skipping file 1877 of 2089: pitch_786.json (already processed)
# Skipping file 1878 of 2089: pitch_787.json (already processed)
# Skipping file 1879 of 2089: pitch_788.json (already processed)
# Skipping file 1880 of 2089: pitch_789.json (already processed)
# Skipping file 1881 of 2089: pitch_79.json (already processed)
# Skipping file 1882 of 2089: pitch_790.json (already processed)
# Skipping file 1883 of 2089: pitch_791.json (already processed)
# Skipping file 1884 of 2089: pitch_792.json (already processed)
# Skipping file 1885 of 2089: pitch_793.json (already processed)
# Skipping file 1886 of 2089: pitch_794.json (already processed)
# Skipping file 1887 of 2089: pitch_795.json (already processed)
# Skipping file 1888 of 2089: pitch_796.json (already processed)
# Skipping file 1889 of 2089: pitch_797.json (already processed)
# Skipping file 1890 of 2089: pitch_798.json (already processed)
# Skipping file 1891 of 2089: pitch_799.json (already processed)
# Skipping file 1892 of 2089: pitch_8.json (already processed)
# Skipping file 1893 of 2089: pitch_80.json (already processed)
# Skipping file 1894 of 2089: pitch_800.json (already processed)
# Skipping file 1895 of 2089: pitch_801.json (already processed)
# Skipping file 1896 of 2089: pitch_802.json (already processed)
# Skipping file 1897 of 2089: pitch_803.json (already processed)
# Skipping file 1898 of 2089: pitch_804.json (already processed)
# Skipping file 1899 of 2089: pitch_805.json (already processed)
# Skipping file 1900 of 2089: pitch_806.json (already processed)
# Skipping file 1901 of 2089: pitch_807.json (already processed)
# Skipping file 1902 of 2089: pitch_808.json (already processed)
# Skipping file 1903 of 2089: pitch_809.json (already processed)
# Skipping file 1904 of 2089: pitch_81.json (already processed)
# Skipping file 1905 of 2089: pitch_810.json (already processed)
# Skipping file 1906 of 2089: pitch_811.json (already processed)
# Skipping file 1907 of 2089: pitch_812.json (already processed)
# Skipping file 1908 of 2089: pitch_813.json (already processed)
# Skipping file 1909 of 2089: pitch_814.json (already processed)
# Skipping file 1910 of 2089: pitch_815.json (already processed)
# Skipping file 1911 of 2089: pitch_816.json (already processed)
# Skipping file 1912 of 2089: pitch_817.json (already processed)
# Skipping file 1913 of 2089: pitch_818.json (already processed)
# Skipping file 1914 of 2089: pitch_819.json (already processed)
# Skipping file 1915 of 2089: pitch_82.json (already processed)
# Skipping file 1916 of 2089: pitch_820.json (already processed)
# Skipping file 1917 of 2089: pitch_822.json (already processed)
# Skipping file 1918 of 2089: pitch_823.json (already processed)
# Skipping file 1919 of 2089: pitch_824.json (already processed)
# Skipping file 1920 of 2089: pitch_825.json (already processed)
# Skipping file 1921 of 2089: pitch_826.json (already processed)
# Skipping file 1922 of 2089: pitch_827.json (already processed)
# Skipping file 1923 of 2089: pitch_828.json (already processed)
# Skipping file 1924 of 2089: pitch_829.json (already processed)
# Skipping file 1925 of 2089: pitch_83.json (already processed)
# Skipping file 1926 of 2089: pitch_830.json (already processed)
# Skipping file 1927 of 2089: pitch_831.json (already processed)
# Skipping file 1928 of 2089: pitch_832.json (already processed)
# Skipping file 1929 of 2089: pitch_833.json (already processed)
# Skipping file 1930 of 2089: pitch_834.json (already processed)
# Skipping file 1931 of 2089: pitch_835.json (already processed)
# Skipping file 1932 of 2089: pitch_836.json (already processed)
# Skipping file 1933 of 2089: pitch_837.json (already processed)
# Skipping file 1934 of 2089: pitch_838.json (already processed)
# Skipping file 1935 of 2089: pitch_839.json (already processed)
# Skipping file 1936 of 2089: pitch_84.json (already processed)
# Skipping file 1937 of 2089: pitch_840.json (already processed)
# Skipping file 1938 of 2089: pitch_841.json (already processed)
# Skipping file 1939 of 2089: pitch_842.json (already processed)
# Skipping file 1940 of 2089: pitch_843.json (already processed)
# Skipping file 1941 of 2089: pitch_844.json (already processed)
# Skipping file 1942 of 2089: pitch_845.json (already processed)
# Skipping file 1943 of 2089: pitch_846.json (already processed)
# Skipping file 1944 of 2089: pitch_847.json (already processed)
# Skipping file 1945 of 2089: pitch_848.json (already processed)
# Skipping file 1946 of 2089: pitch_849.json (already processed)
# Skipping file 1947 of 2089: pitch_85.json (already processed)
# Skipping file 1948 of 2089: pitch_850.json (already processed)
# Skipping file 1949 of 2089: pitch_851.json (already processed)
# Skipping file 1950 of 2089: pitch_852.json (already processed)
# Skipping file 1951 of 2089: pitch_853.json (already processed)
# Skipping file 1952 of 2089: pitch_854.json (already processed)
# Skipping file 1953 of 2089: pitch_855.json (already processed)
# Skipping file 1954 of 2089: pitch_856.json (already processed)
# Skipping file 1955 of 2089: pitch_857.json (already processed)
# Skipping file 1956 of 2089: pitch_858.json (already processed)
# Skipping file 1957 of 2089: pitch_859.json (already processed)
# Skipping file 1958 of 2089: pitch_86.json (already processed)
# Skipping file 1959 of 2089: pitch_860.json (already processed)
# Skipping file 1960 of 2089: pitch_861.json (already processed)
# Skipping file 1961 of 2089: pitch_862.json (already processed)
# Skipping file 1962 of 2089: pitch_863.json (already processed)
# Skipping file 1963 of 2089: pitch_864.json (already processed)
# Skipping file 1964 of 2089: pitch_865.json (already processed)
# Skipping file 1965 of 2089: pitch_866.json (already processed)
# Skipping file 1966 of 2089: pitch_867.json (already processed)
# Skipping file 1967 of 2089: pitch_868.json (already processed)
# Skipping file 1968 of 2089: pitch_869.json (already processed)
# Skipping file 1969 of 2089: pitch_87.json (already processed)
# Skipping file 1970 of 2089: pitch_870.json (already processed)
# Skipping file 1971 of 2089: pitch_871.json (already processed)
# Skipping file 1972 of 2089: pitch_872.json (already processed)
# Skipping file 1973 of 2089: pitch_873.json (already processed)
# Skipping file 1974 of 2089: pitch_874.json (already processed)
# Skipping file 1975 of 2089: pitch_875.json (already processed)
# Skipping file 1976 of 2089: pitch_876.json (already processed)
# Skipping file 1977 of 2089: pitch_877.json (already processed)
# Skipping file 1978 of 2089: pitch_878.json (already processed)
# Skipping file 1979 of 2089: pitch_879.json (already processed)
# Skipping file 1980 of 2089: pitch_88.json (already processed)
# Skipping file 1981 of 2089: pitch_880.json (already processed)
# Skipping file 1982 of 2089: pitch_881.json (already processed)
# Skipping file 1983 of 2089: pitch_882.json (already processed)
# Skipping file 1984 of 2089: pitch_883.json (already processed)
# Skipping file 1985 of 2089: pitch_884.json (already processed)
# Skipping file 1986 of 2089: pitch_885.json (already processed)
# Skipping file 1987 of 2089: pitch_886.json (already processed)
# Skipping file 1988 of 2089: pitch_887.json (already processed)
# Skipping file 1989 of 2089: pitch_888.json (already processed)
# Skipping file 1990 of 2089: pitch_89.json (already processed)
# Skipping file 1991 of 2089: pitch_890.json (already processed)
# Skipping file 1992 of 2089: pitch_891.json (already processed)
# Skipping file 1993 of 2089: pitch_892.json (already processed)
# Skipping file 1994 of 2089: pitch_893.json (already processed)
# Skipping file 1995 of 2089: pitch_894.json (already processed)
# Skipping file 1996 of 2089: pitch_895.json (already processed)
# Skipping file 1997 of 2089: pitch_896.json (already processed)
# Skipping file 1998 of 2089: pitch_897.json (already processed)
# Skipping file 1999 of 2089: pitch_898.json (already processed)
# Skipping file 2000 of 2089: pitch_899.json (already processed)
# Skipping file 2001 of 2089: pitch_9.json (already processed)
# Skipping file 2002 of 2089: pitch_90.json (already processed)
# Skipping file 2003 of 2089: pitch_900.json (already processed)
# Skipping file 2004 of 2089: pitch_901.json (already processed)
# Skipping file 2005 of 2089: pitch_902.json (already processed)
# Skipping file 2006 of 2089: pitch_903.json (already processed)
# Skipping file 2007 of 2089: pitch_904.json (already processed)
# Skipping file 2008 of 2089: pitch_905.json (already processed)
# Skipping file 2009 of 2089: pitch_906.json (already processed)
# Skipping file 2010 of 2089: pitch_907.json (already processed)
# Skipping file 2011 of 2089: pitch_908.json (already processed)
# Skipping file 2012 of 2089: pitch_909.json (already processed)
# Skipping file 2013 of 2089: pitch_91.json (already processed)
# Skipping file 2014 of 2089: pitch_910.json (already processed)
# Skipping file 2015 of 2089: pitch_911.json (already processed)
# Skipping file 2016 of 2089: pitch_912.json (already processed)
# Skipping file 2017 of 2089: pitch_913.json (already processed)
# Skipping file 2018 of 2089: pitch_914.json (already processed)
# Skipping file 2019 of 2089: pitch_915.json (already processed)
# Skipping file 2020 of 2089: pitch_916.json (already processed)
# Skipping file 2021 of 2089: pitch_917.json (already processed)
# Skipping file 2022 of 2089: pitch_918.json (already processed)
# Skipping file 2023 of 2089: pitch_919.json (already processed)
# Skipping file 2024 of 2089: pitch_920.json (already processed)
# Skipping file 2025 of 2089: pitch_921.json (already processed)
# Skipping file 2026 of 2089: pitch_922.json (already processed)
# Skipping file 2027 of 2089: pitch_923.json (already processed)
# Skipping file 2028 of 2089: pitch_924.json (already processed)
# Skipping file 2029 of 2089: pitch_925.json (already processed)
# Skipping file 2030 of 2089: pitch_926.json (already processed)
# Skipping file 2031 of 2089: pitch_927.json (already processed)
# Skipping file 2032 of 2089: pitch_928.json (already processed)
# Skipping file 2033 of 2089: pitch_929.json (already processed)
# Skipping file 2034 of 2089: pitch_93.json (already processed)
# Skipping file 2035 of 2089: pitch_930.json (already processed)
# Skipping file 2036 of 2089: pitch_931.json (already processed)
# Skipping file 2037 of 2089: pitch_932.json (already processed)
# Skipping file 2038 of 2089: pitch_933.json (already processed)
# Skipping file 2039 of 2089: pitch_934.json (already processed)
# Skipping file 2040 of 2089: pitch_935.json (already processed)
# Skipping file 2041 of 2089: pitch_936.json (already processed)
# Skipping file 2042 of 2089: pitch_937.json (already processed)
# Skipping file 2043 of 2089: pitch_938.json (already processed)
# Skipping file 2044 of 2089: pitch_94.json (already processed)
# Skipping file 2045 of 2089: pitch_940.json (already processed)
# Skipping file 2046 of 2089: pitch_941.json (already processed)
# Skipping file 2047 of 2089: pitch_942.json (already processed)
# Skipping file 2048 of 2089: pitch_943.json (already processed)
# Skipping file 2049 of 2089: pitch_944.json (already processed)
# Skipping file 2050 of 2089: pitch_945.json (already processed)
# Skipping file 2051 of 2089: pitch_946.json (already processed)
# Skipping file 2052 of 2089: pitch_947.json (already processed)
# Skipping file 2053 of 2089: pitch_948.json (already processed)
# Skipping file 2054 of 2089: pitch_949.json (already processed)
# Skipping file 2055 of 2089: pitch_95.json (already processed)
# Skipping file 2056 of 2089: pitch_950.json (already processed)
# Skipping file 2057 of 2089: pitch_951.json (already processed)
# Skipping file 2058 of 2089: pitch_952.json (already processed)
# Skipping file 2059 of 2089: pitch_953.json (already processed)
# Skipping file 2060 of 2089: pitch_954.json (already processed)
# Skipping file 2061 of 2089: pitch_955.json (already processed)
# Skipping file 2062 of 2089: pitch_957.json (already processed)
# Skipping file 2063 of 2089: pitch_958.json (already processed)
# Skipping file 2064 of 2089: pitch_959.json (already processed)
# Skipping file 2065 of 2089: pitch_96.json (already processed)
# Skipping file 2066 of 2089: pitch_960.json (already processed)
# Skipping file 2067 of 2089: pitch_961.json (already processed)
# Skipping file 2068 of 2089: pitch_962.json (already processed)
# Skipping file 2069 of 2089: pitch_963.json (already processed)
# Skipping file 2070 of 2089: pitch_964.json (already processed)
# Skipping file 2071 of 2089: pitch_965.json (already processed)
# Skipping file 2072 of 2089: pitch_966.json (already processed)
# Skipping file 2073 of 2089: pitch_967.json (already processed)
# Skipping file 2074 of 2089: pitch_968.json (already processed)
# Skipping file 2075 of 2089: pitch_969.json (already processed)
# Skipping file 2076 of 2089: pitch_97.json (already processed)
# Skipping file 2077 of 2089: pitch_970.json (already processed)
# Skipping file 2078 of 2089: pitch_971.json (already processed)
# Skipping file 2079 of 2089: pitch_972.json (already processed)
# Skipping file 2080 of 2089: pitch_973.json (already processed)
# Skipping file 2081 of 2089: pitch_974.json (already processed)
# Skipping file 2082 of 2089: pitch_975.json (already processed)
# Skipping file 2083 of 2089: pitch_976.json (already processed)
# Skipping file 2084 of 2089: pitch_977.json (already processed)
# Skipping file 2085 of 2089: pitch_978.json (already processed)
# Skipping file 2086 of 2089: pitch_979.json (already processed)
# Skipping file 2087 of 2089: pitch_98.json (already processed)
# Skipping file 2088 of 2089: pitch_980.json (already processed)
# Skipping file 2089 of 2089: pitch_99.json (already processed)
# Processing complete.  Processed 17 files, skipped 2072 files.
# Processing complete.

# %% [markdown]
# <a href="https://colab.research.google.com/github/adhilbinmujeeb/Business-Model-Evaluation-letsgetmoving/blob/main/Clean_subtitles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re

def clean_youtube_subtitles(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    cleaned_lines = []
    for line in lines:
        # Remove timestamp and alignment tags
        line = re.sub(r'\d{2}:\d{2}:\d{2}\.\d{3} --> \d{2}:\d{2}:\d{2}\.\d{3}', '', line)
        line = re.sub(r'align:start position:\d+%', '', line)

        # Remove <c> tags and other tags like <...>
        line = re.sub(r'<[^>]*>', '', line)

        # Strip extra spaces and add cleaned line if it's not empty
        line = line.strip()
        if line:
            cleaned_lines.append(line)

    # Write the cleaned lines to the output file
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write("\n".join(cleaned_lines))

    print(f"Cleaned subtitles saved to {output_file}")

def clean_subtitles_in_folder(folder_path, output_folder):
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        input_file = os.path.join(folder_path, filename)
        if os.path.isfile(input_file) and filename.endswith('.vtt'):  # Only process .txt files
            output_file = os.path.join(output_folder, f"cleaned_{filename}")
            clean_youtube_subtitles(input_file, output_file)

# Example usage in Google Colab
folder_path = '/content/shark_tank_global'  # Replace with your folder path
output_folder = '/content/cln_sharktank_global'  # Replace with your output folder path

# Make sure the output folder exists
os.makedirs(output_folder, exist_ok=True)

clean_subtitles_in_folder(folder_path, output_folder)
# Out:
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_2L9z6jL7TQ4.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_YsTO0ih9HPY.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Zfv8FqzNoyQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_LCajDC1_d7E.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_O1B27Z2FKQQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_izHcx7oVqkk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_MBDLlYiHTeM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Uej5cBdLreM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_nkPrDsD4YmE.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_fuM1Vh7OgfY.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_afb9CNiNz08.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_wTz2mSnQUwQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_r0-vM2uZHN8.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_rkuDUkOGDRQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_28l_jaSpNXM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_EZeN8RPxxaU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_q_LIMEF-v7k.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Q7K6ZdYownU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_wHL3eoUIrPU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_jjaY_cWr8EQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_bjhkVQ8Srys.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned__OuuBPrFuzQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_4gk5k8gp78k.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_2PWait_Hfvw.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_DR6B9KKgd9k.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Q8dMSahfmqs.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_zEOzqlLJq1g.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_4oJx5ophr3I.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_pkdHZ9fHiNY.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_IDpfl2aGruE.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_j6gzngCo1H0.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_o82icYSBrcs.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_J-oxoex0gys.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_2MlIogDsAcw.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_opUaZxDk4Tg.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Lbnd1A6H5hM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_daJRTaQnQ0Q.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_N4kdwv5kUxk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_0j3gzmDRL10.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_Fc1yn8k0wUo.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_DMGvT5g7TQM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_5xFfbL8gkqc.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_mUdrwHnJ7jU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_fBGl3ata-K4.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_w1l0_ll_HIU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_j1AqllPwRT4.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_hSQL49siOGo.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_AnlBNC6fpuE.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_361bWx82zrk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_0dViu8lAQN0.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_FbsKto4gg14.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_uNRqyBD3RDk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_et_zjQxl8Sk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_kGIfmfvIqaw.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_HpUR7-Oe1ss.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_AkqKveoqiwk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_4XLe4cvAXkY.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_ZfQY7Q4wtXw.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_a3IGj7YWXuI.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_fylhUz71YJ8.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_GX33DV-zR-I.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_RjshpVyUttw.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_c8HZ-7qED4U.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_YLLSXnyepqA.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned
en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_e_0vu9d1948.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_dwQN0Z-e3Xs.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_aF6V9Yy6MY4.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_ZTXOvLiJKEQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_3q5Xqm2yXo8.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_EkrcEm37foU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_h3rEIgiR1I4.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_s8StWN-eWlE.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_QMO5SYMolvA.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_xA_AvZu1qMc.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_bpX_Sp7Y5e0.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_NUM-MtXHWJs.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_keXRBCh-igs.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_FykmggqWOmM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_xNOvX69NdGo.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_-YK-iFmzWrc.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_72sGSDpDv1c.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_pgLsVenC_Pk.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_nbidOLT0N5s.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_UWWB17g0AKM.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_5hEeDh5hoPQ.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_zKQQvC6mHMU.en.vtt
# Cleaned subtitles saved to /content/cln_sharktank_global/cleaned_xZp8XLmnbSM.en.vtt

# %%
import shutil
import os
from google.colab import files

# Define the list of folders you want to zip
folders = ['/content/cln_dragon_den_canada', '/content/cln_dragon_den_global', '/content/cln_dragon_den_ireland','/content/cln_dragon_den_uk','/content/cln_sharktank_aus','/content/cln_sharktank_global']  # Replace with your folder paths

# Temporary directory to combine all folders
temp_dir = '/content/temp_folders'

# Create the temp directory
os.makedirs(temp_dir, exist_ok=True)

# Move all folders into the temp directory
for folder in folders:
    shutil.copytree(folder, os.path.join(temp_dir, os.path.basename(folder)))

# Zip the combined folder
output_zip = '/content/multiple_folders.zip'
shutil.make_archive(output_zip.replace('.zip', ''), 'zip', temp_dir)

# Download the zipped file
files.download(output_zip)

# %%
import os

def clean_and_save_subtitles(file_path):
    """
    Cleans a single .vtt file by removing duplicate lines and saves the result as a .txt file.
    """
    unique_lines = []
    seen = set()

    # Read the .vtt file
    with open(file_path, "r", encoding="utf-8") as file:
        lines = file.readlines()

    # Remove duplicates while maintaining order
    for line in lines:
        stripped_line = line.strip()
        if stripped_line and stripped_line not in seen:
            seen.add(stripped_line)
            unique_lines.append(stripped_line)

    # Save the cleaned file as a .txt file
    cleaned_file_path = file_path.replace(".vtt", "_cleaned.txt")
    with open(cleaned_file_path, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write("\n".join(unique_lines))

    print(f"Cleaned and saved: {cleaned_file_path}")

def process_all_vtt_files(folder_path):
    """
    Processes all .vtt files in a folder, cleaning and saving them as .txt files.
    """
    # Get all .vtt files in the folder
    vtt_files = [f for f in os.listdir(folder_path) if f.endswith(".vtt")]

    if not vtt_files:
        print("No .vtt files found in the specified folder.")
        return

    print(f"Found {len(vtt_files)} .vtt files. Cleaning...")
    for vtt_file in vtt_files:
        full_path = os.path.join(folder_path, vtt_file)
        clean_and_save_subtitles(full_path)
    print("All .vtt files processed.")

# Specify the folder containing your .vtt files
folder_path = "/content/cln_dragon_den_canada"  # Replace with the path to your folder
process_all_vtt_files(folder_path)
# Out:
# Found 179 .vtt files. Cleaning...
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_PI9lcw10cBo.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_2CnPfB6Cyc8.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_0sWq4Yedrxg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_zBgZL3WT_go.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_XoqZyFFYxO8.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_hOyw6ZUvHbI.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_NdtFX862roc.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_vuBGAlUuR0E.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_yn6Pj4b_IKQ.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_Gzo1Jav5QtI.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_2Bb_jOiBQ0c.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned
en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_XVs9yVknluY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_QXjwg4ucTa8.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_uSs_n3_gnTI.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_KuksR2xrnpQ.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_4czrov956pU.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_GFRnj7ZkZ8Q.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_TcBqe5ih5Dw.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_CdcK1wWy9Tk.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_dMDGjKj1nc0.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_qeGBjavxIVg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_mzcwb1sLQWw.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_6kFM8cZx2Ek.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_ITOyQT8OzJg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_5YCKhHvzia0.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_vdn95YDPMzY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_M66NX78xGIg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_qoCFu8ydcTA.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_AnR8bc1VCpA.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_CGXU6MSy_4g.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_5xmzC2DVqAw.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_iOjUGBw1x5o.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_cBb2N6K20fY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_RkI5U8RMSO8.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_g1baSUM7jL4.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_P0LW6Igg9wU.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_GslnkwxdzjQ.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_jIFtN-J25oY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned__lzbsmSerXo.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_tg6PCfxeKrg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_9RRszdzWrrA.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_O39yqDru7ik.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_UHxVrnuiG38.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_l4_y8smjnjs.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_e6iCTM8EEKg.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_BoBQFDrTGLI.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_sIIyTZjQ684.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_5bH5tUinN5I.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_-SsHPpuinW0.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_JRR1sJM0gl0.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_cFZKpNrwVAY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_dRnLxIgiaQ8.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_YWrmD3OGpJA.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_A4jl9CFFdR0.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_c5E65xABeIE.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_kW25tuv0EGA.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_Y2YT4tIUJmY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_m0N8c7VJj9U.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_eUSbxL2K-70.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_aSl7CMhASV4.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_5jZmiTwJ7hY.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_zEbHUmYClqE.en_cleaned.txt
# Cleaned and saved: /content/cln_dragon_den_canada/cleaned_0QhZa1hDl60.en_cleaned.txt
# All .vtt files processed.

# %%
import os

def clean_and_save_subtitles(file_path, output_folder):
    """
    Cleans a single .vtt file by removing duplicate lines and saves the result as a .txt file in a specified folder.
    """
    unique_lines = []
    seen = set()

    # Read the .vtt file
    with open(file_path, "r", encoding="utf-8") as file:
        lines = file.readlines()

    # Remove duplicates while maintaining order
    for line in lines:
        stripped_line = line.strip()
        if stripped_line and stripped_line not in seen:
            seen.add(stripped_line)
            unique_lines.append(stripped_line)

    # Save the cleaned file as a .txt file in the new folder
    file_name = os.path.basename(file_path).replace(".vtt", "_cleaned.txt")
    cleaned_file_path = os.path.join(output_folder, file_name)
    with open(cleaned_file_path, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write("\n".join(unique_lines))

    print(f"Cleaned and saved: {cleaned_file_path}")

def process_all_vtt_files(folder_path):
    """
    Processes all .vtt files in a folder, cleaning and saving them as .txt files in a new folder.
    """
    # Get all .vtt files in the folder
    vtt_files = [f for f in os.listdir(folder_path) if f.endswith(".vtt")]

    if not vtt_files:
        print("No .vtt files found in the specified folder.")
        return

    # Create a new folder to store cleaned .txt files
    output_folder = os.path.join(folder_path, "cleaned_txt_files")
    os.makedirs(output_folder, exist_ok=True)

    print(f"Found {len(vtt_files)} .vtt files. Cleaning...")
    for vtt_file in vtt_files:
        full_path = os.path.join(folder_path, vtt_file)
        clean_and_save_subtitles(full_path, output_folder)
    print(f"All .vtt files processed. Cleaned files are saved in: {output_folder}")

# Specify the folder containing your .vtt files
folder_path = "/content/cln_sharktank_global"  # Replace with the path to your folder
process_all_vtt_files(folder_path)
# Out:
# Found 321 .vtt files. Cleaning...
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned
.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_dYPftEHallQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_KRZvjjaFQ4k.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_a3IGj7YWXuI.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_35RfW4rAHy8.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_vOOOqmKjQIs.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_oGoY8Zqm9lo.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_l1GcXxjMabc.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_2L9z6jL7TQ4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_bkUAquUk26w.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_vd2VsNWSiu0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_EZeN8RPxxaU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_pQj-Gd48Eb8.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_kGIfmfvIqaw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_5xFfbL8gkqc.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_odUyNc-_tsw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_j6gzngCo1H0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_brNm9EtLijs.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_8MdWk5sj3sw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_2Mlx_O0oxqM.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_Vj9Ome-5Ly8.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_xNOvX69NdGo.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_pYGqTDA1df4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_ehgyV-g1br4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_rZCM3FzvOqQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_J-oxoex0gys.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_pkdHZ9fHiNY.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_WXwAhNr5srk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_ae5MssJ8en4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_lhgmIEdM0xo.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_zKQQvC6mHMU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_0dViu8lAQN0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_9v6AFKrg1vI.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_XcIxN6ALj4c.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_oYUo7yam5tA.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_Kaq3r-yTQ1A.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_92cC2OdjxTk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_lvP3AfIddI8.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_yhjqY6Ps8p4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_7LQTKgmv_Gk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_Wyn_O4ubQvU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_361bWx82zrk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_KUW6TSib3Uk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_nlVhx46TQFg.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_Fc1yn8k0wUo.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_0j3gzmDRL10.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_FdoMOd5JFwA.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_TvAkbbwV1BU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_NkL7aaMamLM.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_uSeoHKYLwwA.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_RGFhzCNGAIk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_DknZrVpMQnQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_uKJQLxByVrg.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_9_6fXlOSNDQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_G5qwJrDsMaw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_sAto3yCMwkM.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_4gk5k8gp78k.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_kMHaWEfjGdQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_9iOdIt8iR2U.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_72sGSDpDv1c.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_6n7Zw7Tkc2Q.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_ehhY-Btq8u4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_dBf7sD5uTxQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_2qYwZZj5WNs.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_3raiovWj-Q4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_BUqy99t_fhQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_qc4bucvjar4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_Q7K6ZdYownU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_CDKZT8ESDco.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_64geD9iQiHw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned__ALNAzjGEw0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_AKvdLxKCmmo.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_xYd7uBBRfE0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_kfRAYiy0WV0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_gZalh9tIZks.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_s8StWN-eWlE.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_stqAfPzTfcc.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_acXeHedChAM.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_XNaQCOsoHlc.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_ljEdoe3dF8g.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_P-9lDAiN26U.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_2MlIogDsAcw.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_V6NZLTsMDyM.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_mUdrwHnJ7jU.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_RYgctaQ-nU4.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_2ucJUn6cd4U.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_wqjOcJp2v20.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_rsj3bCw5zuc.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_dlfKjBU7Wt0.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_cpxiIVgqgGA.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_O1B27Z2FKQQ.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_uN1SQq-o1XE.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_IHdIve1prBk.en_cleaned.txt
# Cleaned and saved: /content/cln_sharktank_global/cleaned_txt_files/cleaned_AnlBNC6fpuE.en_cleaned.txt
# All .vtt files processed. Cleaned files are saved in: /content/cln_sharktank_global/cleaned_txt_files

# %%
import shutil

# Replace 'your_folder_name' with the name of your folder in Colab
folder_name = "/content/cln_sharktank_global/cleaned_txt_files"
shutil.make_archive(folder_name, 'zip', folder_name)
# Out:
# '/content/cln_sharktank_global/cleaned_txt_files.zip'

# %%
from google.colab import files

# Replace 'your_folder_name.zip' with the name of the zipped file
files.download(f"/content/cln_sharktank_global/cleaned_txt_files.zip")
